# %% [markdown]
# # 人脸生成（Face Generation）
# 在该项目中，你将使用生成式对抗网络（Generative Adversarial Nets）来生成新的人脸图像。
# ### 获取数据
# 该项目将使用以下数据集：
# - MNIST
# - CelebA
#
# 由于 CelebA 数据集比较复杂，而且这是你第一次使用 GANs。我们想让你先在 MNIST 数据集上测试你的 GANs 模型，以让你更快的评估所建立模型的性能。
#
# 如果你在使用 [FloydHub](https://www.floydhub.com/), 请将 `data_dir` 设置为 "/input" 并使用 [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## 探索数据（Explore the Data）
# ### MNIST
# [MNIST](http://yann.lecun.com/exdb/mnist/) 是一个手写数字的图像数据集。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) 是一个包含 20 多万张名人图片及相关图片说明的数据集。你将用此数据集生成人脸，不会用不到相关说明。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## 预处理数据（Preprocess the Data）
# 由于该项目的重点是建立 GANs 模型，我们将为你预处理数据。
#
# 经过数据预处理，MNIST 和 CelebA 数据集的值在 28×28 维度图像的 [-0.5, 0.5] 范围内。CelebA 数据集中的图像裁剪了非脸部的图像部分，然后调整到 28x28 维度。
#
# MNIST 数据集中的图像是单[通道](https://en.wikipedia.org/wiki/Channel_(digital_image%29)的黑白图像，CelebA 数据集中的图像是 [三通道的 RGB 彩色图像](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images)。
#
# ## 建立神经网络（Build the Neural Network）
# 你将通过部署以下函数来建立 GANs 的主要组成部分:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### 检查 TensorFlow 版本并获取 GPU 型号
# 检查你是否使用正确的 TensorFlow 版本，并获取 GPU 型号

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ### 输入（Input）
# 部署 `model_inputs` 函数以创建用于神经网络的 [占位符 (TF Placeholders)](https://www.tensorflow.org/versions/r0.11/api_docs/python/io_ops/placeholders)。请创建以下占位符：
# - 输入图像占位符: 使用 `image_width`，`image_height` 和 `image_channels` 设置为 rank 4。
# - 输入 Z 占位符: 设置为 rank 2，并命名为 `z_dim`。
# - 学习速率占位符: 设置为 rank 0。
#
# 返回占位符元组的形状为 (tensor of real input images, tensor of z data, learning rate)。

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function

    input_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name="input_real")
    input_z = tf.placeholder(tf.float32, (None, z_dim), name="z_dim")
    l_r = tf.placeholder(tf.float32, name="learning_rate")
    
    return input_real, input_z, l_r


#----
# def model_inputs(real_dim, z_dim):
#     inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
#     inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    
#     return inputs_real, inputs_z
#----

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 辨别器（Discriminator）
# 部署 `discriminator` 函数创建辨别器神经网络以辨别 `images`。该函数应能够重复使用神经网络中的各种变量。 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "discriminator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回形如 (tensor output of the discriminator, tensor logits of the discriminator) 的元组。

# %%
alpha = 0.2
    
def cal_x(inputs, filters, kernel_size):
    return tf.layers.conv2d(inputs, filters, kernel_size, strides = 2, padding="same", \
                            kernel_initializer = tf.contrib.layers.xavier_initializer_conv2d())
    
def cal_bn(inputs):
    return tf.layers.batch_normalization(inputs, training = True)
    
def cal_relu(inputs):
    return tf.maximum(alpha * inputs, inputs)

def discriminator(images, reuse = False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function

    with tf.variable_scope("discriminator", reuse = reuse):
        x1 = cal_x(images, 128, 5)
        bn1 = cal_bn(x1)
        relu1 = cal_relu(bn1)
        
        x2 = cal_x(relu1, 256, 5)
        bn2 = cal_bn(x2)
        relu2 = cal_relu(bn2)
        
        x3 = cal_x(relu2, 512, 5)
        bn3 = cal_bn(x3)
        relu3 = cal_relu(bn3)
        
        flat = tf.contrib.layers.flatten(relu3)
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits

    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 生成器（Generator）
# 部署 `generator` 函数以使用 `z` 生成图像。该函数应能够重复使用神经网络中的各种变量。
# 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "generator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回所生成的 28 x 28 x `out_channel_dim` 维度图像。

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function

    reuse = False if is_train else True
    
    with tf.variable_scope("generator", reuse = reuse):

        x1 = tf.layers.dense(z, 7 * 7 * 512)
        x1 = tf.reshape(x1, (-1, 7, 7, 512))
        x1 = tf.layers.batch_normalization(x1, training = is_train)
        x1 = cal_relu(x1)
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides = 2, padding = "same")
        x2 = tf.layers.batch_normalization(x2, training = is_train)
        x2 = cal_relu(x2)
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides = 1, padding = "same")
        x3 = tf.layers.batch_normalization(x3, training = is_train)
        x3 = cal_relu(x3)
        
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides = 1, padding = "same")
        out = tf.tanh(logits)

    return out
 
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 损失函数（Loss）
# 部署 `model_loss` 函数训练并计算 GANs 的损失。该函数应返回形如 (discriminator loss, generator loss) 的元组。
#
# 使用你已实现的函数：
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    smooth = 0.1
    
    g_model = generator(input_z, out_channel_dim, is_train = True)
    d_model_real, d_logits_real = discriminator(input_real, reuse = False)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse = True)

    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(\
                                 logits = d_logits_real, labels = tf.ones_like(d_model_real) * (1 - smooth)))
    
    d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(\
                                 logits = d_logits_fake, labels = tf.zeros_like(d_model_fake) * (1 - smooth)))
    
    d_loss = d_loss_real + d_loss_fake
    
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(\
                            logits = d_logits_fake, labels = tf.ones_like(d_model_fake) * (1 - smooth)))

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### 优化（Optimization）
# 部署 `model_opt` 函数实现对 GANs 的优化。使用 [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) 获取可训练的所有变量。通过变量空间名 `discriminator` 和 `generator` 来过滤变量。该函数应返回形如 (discriminator training operation, generator training operation) 的元组。

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [i for i in t_vars if i.name.startswith("discriminator")]
    g_vars = [j for j in t_vars if j.name.startswith("generator")]

    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    gen_updates = [k for k in update_ops if k.name.startswith("generator")]
    d_train_opt = tf.train.AdamOptimizer(learning_rate = learning_rate, beta1 = beta1 \
                                        ).minimize(d_loss, var_list = d_vars)
    
    with tf.control_dependencies(gen_updates):
        g_train_opt = tf.train.AdamOptimizer(learning_rate = learning_rate, beta1 = beta1 \
                                            ).minimize(g_loss, var_list = g_vars)
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络（Neural Network Training）
# ### 输出显示
# 使用该函数可以显示生成器 (Generator) 在训练过程中的当前输出，这会帮你评估 GANs 模型的训练程度。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap = cmap)
    pyplot.show()

# %% [markdown]
# ### 训练
# 部署 `train` 函数以建立并训练 GANs 模型。记得使用以下你已完成的函数：
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# 使用 `show_generator_output` 函数显示 `generator` 在训练过程中的输出。
#
# **注意**：在每个批次 (batch) 中运行 `show_generator_output` 函数会显著增加训练时间与该 notebook 的体积。推荐每 100 批次输出一次 `generator` 的输出。

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    image_width = data_shape[1]
    image_height = data_shape[2]
    if (data_image_mode == "RGB"):
        image_channels = 3
    else:
        image_channels = 1
    
    input_real, input_z, l_r = model_inputs(image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    #--- Check from here. unOs.Z
#     print_batch = 20
#     time_to_show_g_output = 100
    steps = 0
    losses = []
    samples = []
    
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                
                steps += 1
                batch_images *= 2
                batch_z = np.random.uniform(-1, 1, size = (batch_size, z_dim))
                
                _ = sess.run(d_train_opt, feed_dict = {input_real: batch_images, input_z: batch_z})
                _ = sess.run(g_train_opt, feed_dict = {input_z: batch_z, l_r:learning_rate})
                # Run it 2 times to prevent d_loss become 0
                _ = sess.run(g_train_opt, feed_dict = {input_z: batch_z, l_r:learning_rate})
                
                while steps % 20 == 0:
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}    ".format(epoch_i + 1, epoch_count),
                          "Discriminator Loss: {:.4f}    ".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                while steps % 100 == 0:
                    show_generator_output(sess, show_batch, input_z, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# 在 MNIST 上测试你的 GANs 模型。经过 2 次迭代，GANs 应该能够生成类似手写数字的图像。确保生成器 (generator) 低于辨别器 (discriminator) 的损失，或接近 0。

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.001
beta1 = 0.5


import time
MNIST_start_time = time.time()

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)

    
MNIST_end_time = time.time()
print("\nTime cost: {:.2f} minutes".format((MNIST_end_time - MNIST_start_time) / 60))
# Out:
# Epoch 1/2     Discriminator Loss: 1.3854     Generator Loss: 1.7335
# Epoch 1/2     Discriminator Loss: 1.4612     Generator Loss: 1.7455
# Epoch 1/2     Discriminator Loss: 1.4404     Generator Loss: 1.7628
# Epoch 1/2     Discriminator Loss: 1.4321     Generator Loss: 1.7278
# Epoch 1/2     Discriminator Loss: 1.4356     Generator Loss: 1.7449
# Epoch 1/2     Discriminator Loss: 1.3410     Generator Loss: 1.7483
# Epoch 1/2     Discriminator Loss: 1.4086     Generator Loss: 1.7357
# Epoch 1/2     Discriminator Loss: 1.3844     Generator Loss: 1.7716
# Epoch 1/2     Discriminator Loss: 1.3463     Generator Loss: 1.7421
# Epoch 1/2     Discriminator Loss: 1.3688     Generator Loss: 1.6912
# Epoch 1/2     Discriminator Loss: 1.4039     Generator Loss: 1.7317
# Epoch 1/2     Discriminator Loss: 1.3908     Generator Loss: 1.7920
# Epoch 1/2     Discriminator Loss: 1.3964     Generator Loss: 1.8025
# Epoch 1/2     Discriminator Loss: 1.3803     Generator Loss: 1.6978
# Epoch 1/2     Discriminator Loss: 1.3901     Generator Loss: 1.8033
# Epoch 1/2     Discriminator Loss: 1.3552     Generator Loss: 1.7407
# Epoch 1/2     Discriminator Loss: 1.4585     Generator Loss: 1.7644
# Epoch 1/2     Discriminator Loss: 1.4122     Generator Loss: 1.7750
# Epoch 1/2     Discriminator Loss: 1.4308     Generator Loss: 1.7290
# Epoch 1/2     Discriminator Loss: 1.4410     Generator Loss: 1.7028
# Epoch 1/2     Discriminator Loss: 1.4148     Generator Loss: 1.7562
# Epoch 1/2     Discriminator Loss: 1.3982     Generator Loss: 1.7500
# Epoch 1/2     Discriminator Loss: 1.3527     Generator Loss: 1.7399
# Epoch 1/2     Discriminator Loss: 1.4686     Generator Loss: 1.7373
# Epoch 1/2     Discriminator Loss: 1.4439     Generator Loss: 1.7616
# Epoch 1/2     Discriminator Loss: 1.4342     Generator Loss: 1.7396
# Epoch 1/2     Discriminator Loss: 1.4477     Generator Loss: 1.7370
# Epoch 1/2     Discriminator Loss: 1.4429     Generator Loss: 1.7520
# Epoch 1/2     Discriminator Loss: 1.4071     Generator Loss: 1.8042
# Epoch 1/2     Discriminator Loss: 1.3844     Generator Loss: 1.7187
# Epoch 1/2     Discriminator Loss: 1.3843     Generator Loss: 1.7584
# Epoch 1/2     Discriminator Loss: 1.4550     Generator Loss: 1.7946
# Epoch 1/2     Discriminator Loss: 1.4168     Generator Loss: 1.8055
# Epoch 1/2     Discriminator Loss: 1.3941     Generator Loss: 1.7954
# Epoch 1/2     Discriminator Loss: 1.4860     Generator Loss: 1.7284
# Epoch 1/2     Discriminator Loss: 1.4788     Generator Loss: 1.7357
# Epoch 1/2     Discriminator Loss: 1.4148     Generator Loss: 1.6923
# Epoch 1/2     Discriminator Loss: 1.3845     Generator Loss: 1.7427
# Epoch 1/2     Discriminator Loss: 1.4114     Generator Loss: 1.7948
# Epoch 1/2     Discriminator Loss: 1.4212     Generator Loss: 1.7831
# Epoch 1/2     Discriminator Loss: 1.3902     Generator Loss: 1.7403
# Epoch 1/2     Discriminator Loss: 1.3978     Generator Loss: 1.7743
# Epoch 1/2     Discriminator Loss: 1.4356     Generator Loss: 1.7628
# Epoch 1/2     Discriminator Loss: 1.4170     Generator Loss: 1.7869
# Epoch 1/2     Discriminator Loss: 1.4251     Generator Loss: 1.7431
# Epoch 1/2     Discriminator Loss: 1.4117     Generator Loss: 1.7401
# Epoch 1/2     Discriminator Loss: 1.4020     Generator Loss: 1.6896
# Epoch 1/2     Discriminator Loss: 1.4940     Generator Loss: 1.7326
# Epoch 1/2     Discriminator Loss: 1.3814     Generator Loss: 1.7063
# Epoch 1/2     Discriminator Loss: 1.4026     Generator Loss: 1.6783
# Epoch 1/2     Discriminator Loss: 1.4059     Generator Loss: 1.7624
# Epoch 1/2     Discriminator Loss: 1.4334     Generator Loss: 1.7222
# Epoch 1/2     Discriminator Loss: 1.4523     Generator Loss: 1.7408
# Epoch 1/2     Discriminator Loss: 1.4038     Generator Loss: 1.7739
# Epoch 1/2     Discriminator Loss: 1.3988     Generator Loss: 1.7701
# Epoch 1/2     Discriminator Loss: 1.3954     Generator Loss: 1.7768
# Epoch 1/2     Discriminator Loss: 1.4678     Generator Loss: 1.7935
# Epoch 1/2     Discriminator Loss: 1.4283     Generator Loss: 1.6904
# Epoch 1/2     Discriminator Loss: 1.5291     Generator Loss: 1.7529
# Epoch 1/2     Discriminator Loss: 1.3854     Generator Loss: 1.7656
# Epoch 1/2     Discriminator Loss: 1.4248     Generator Loss: 1.7352
# Epoch 1/2     Discriminator Loss: 1.3295     Generator Loss: 1.7967
# Epoch 1/2     Discriminator Loss: 1.3983     Generator Loss: 1.7283
# Epoch 1/2     Discriminator Loss: 1.3973     Generator Loss: 1.7355
# Epoch 1/2     Discriminator Loss: 1.4137     Generator Loss: 1.7086
# Epoch 1/2     Discriminator Loss: 1.4216     Generator Loss: 1.7357
# Epoch 1/2     Discriminator Loss: 1.3509     Generator Loss: 1.8089
# Epoch 1/2     Discriminator Loss: 1.4234     Generator Loss: 1.7141
# Epoch 1/2     Discriminator Loss: 1.4825     Generator Loss: 1.7458
# Epoch 1/2     Discriminator Loss: 1.4214     Generator Loss: 1.7965
# Epoch 1/2     Discriminator Loss: 1.3817     Generator Loss: 1.7377
# Epoch 1/2     Discriminator Loss: 1.4070     Generator Loss: 1.7888
# Epoch 1/2     Discriminator Loss: 1.4119     Generator Loss: 1.7002
# Epoch 1/2     Discriminator Loss: 1.3801     Generator Loss: 1.7636
# Epoch 1/2     Discriminator Loss: 1.4110     Generator Loss: 1.7781
# Epoch 1/2     Discriminator Loss: 1.4251     Generator Loss: 1.7573
# Epoch 1/2     Discriminator Loss: 1.4731     Generator Loss: 1.6929
# Epoch 1/2     Discriminator Loss: 1.3986     Generator Loss: 1.7453
# Epoch 1/2     Discriminator Loss: 1.4219     Generator Loss: 1.7570
# Epoch 1/2     Discriminator Loss: 1.4248     Generator Loss: 1.7579
# Epoch 1/2     Discriminator Loss: 1.4412     Generator Loss: 1.7304
# Epoch 1/2     Discriminator Loss: 1.3871     Generator Loss: 1.7796
# Epoch 1/2     Discriminator Loss: 1.3664     Generator Loss: 1.7440
# Epoch 1/2     Discriminator Loss: 1.3983     Generator Loss: 1.7244
# Epoch 1/2     Discriminator Loss: 1.4280     Generator Loss: 1.7340
# Epoch 1/2     Discriminator Loss: 1.4121     Generator Loss: 1.7012
# Epoch 1/2     Discriminator Loss: 1.4222     Generator Loss: 1.7944
# Epoch 1/2     Discriminator Loss: 1.4131     Generator Loss: 1.7718
# Epoch 1/2     Discriminator Loss: 1.3783     Generator Loss: 1.7369
# Epoch 1/2     Discriminator Loss: 1.3987     Generator Loss: 1.7774
# Epoch 1/2     Discriminator Loss: 1.4860     Generator Loss: 1.7173
# Epoch 1/2     Discriminator Loss: 1.3957     Generator Loss: 1.7234
# Epoch 1/2     Discriminator Loss: 1.4642     Generator Loss: 1.6986
# Epoch 1/2     Discriminator Loss: 1.4668     Generator Loss: 1.7753
# Epoch 1/2     Discriminator Loss: 1.3536     Generator Loss: 1.7153
# Epoch 1/2     Discriminator Loss: 1.4466     Generator Loss: 1.7744
# Epoch 1/2     Discriminator Loss: 1.4243     Generator Loss: 1.7570
# Epoch 1/2     Discriminator Loss: 1.4060     Generator Loss: 1.7431
# Epoch 1/2     Discriminator Loss: 1.3932     Generator Loss: 1.7716
# Epoch 1/2     Discriminator Loss: 1.3533     Generator Loss: 1.7440
# Epoch 1/2     Discriminator Loss: 1.3856     Generator Loss: 1.7363
# Epoch 1/2     Discriminator Loss: 1.3710     Generator Loss: 1.7747
# Epoch 1/2     Discriminator Loss: 1.4160     Generator Loss: 1.7218
# Epoch 1/2     Discriminator Loss: 1.4089     Generator Loss: 1.7303
# Epoch 1/2     Discriminator Loss: 1.3767     Generator Loss: 1.7654
# Epoch 1/2     Discriminator Loss: 1.4338     Generator Loss: 1.7021
# Epoch 1/2     Discriminator Loss: 1.3262     Generator Loss: 1.7313
# Epoch 1/2     Discriminator Loss: 1.3916     Generator Loss: 1.7166
# Epoch 1/2     Discriminator Loss: 1.4454     Generator Loss: 1.8258
# Epoch 1/2     Discriminator Loss: 1.4588     Generator Loss: 1.7389
# Epoch 1/2     Discriminator Loss: 1.4023     Generator Loss: 1.7158
# Epoch 1/2     Discriminator Loss: 1.3818     Generator Loss: 1.7813
# Epoch 1/2     Discriminator Loss: 1.4554     Generator Loss: 1.7624
# Epoch 1/2     Discriminator Loss: 1.4492     Generator Loss: 1.7946
# Epoch 1/2     Discriminator Loss: 1.3951     Generator Loss: 1.7331
# Epoch 1/2     Discriminator Loss: 1.4537     Generator Loss: 1.7636
# Epoch 1/2     Discriminator Loss: 1.4279     Generator Loss: 1.7345
# Epoch 1/2     Discriminator Loss: 1.3505     Generator Loss: 1.7237
# Epoch 1/2     Discriminator Loss: 1.4520     Generator Loss: 1.7383
# Epoch 1/2     Discriminator Loss: 1.4344     Generator Loss: 1.7974
# Epoch 1/2     Discriminator Loss: 1.4253     Generator Loss: 1.7138
# Epoch 1/2     Discriminator Loss: 1.3842     Generator Loss: 1.7145
# Epoch 1/2     Discriminator Loss: 1.3776     Generator Loss: 1.7774
# Epoch 1/2     Discriminator Loss: 1.3982     Generator Loss: 1.7425
# Epoch 1/2     Discriminator Loss: 1.4163     Generator Loss: 1.8344
# Epoch 1/2     Discriminator Loss: 1.4482     Generator Loss: 1.8037
# Epoch 1/2     Discriminator Loss: 1.3831     Generator Loss: 1.7268
# Epoch 1/2     Discriminator Loss: 1.4282     Generator Loss: 1.7636
# Epoch 1/2     Discriminator Loss: 1.3848     Generator Loss: 1.7990
# Epoch 1/2     Discriminator Loss: 1.4514     Generator Loss: 1.7322
# Epoch 1/2     Discriminator Loss: 1.3760     Generator Loss: 1.7041
# Epoch 1/2     Discriminator Loss: 1.4249     Generator Loss: 1.7740
# Epoch 1/2     Discriminator Loss: 1.3432     Generator Loss: 1.7758
# Epoch 1/2     Discriminator Loss: 1.4869     Generator Loss: 1.7469
# Epoch 1/2     Discriminator Loss: 1.4542     Generator Loss: 1.6946
# Epoch 1/2     Discriminator Loss: 1.3566     Generator Loss: 1.7765
# Epoch 1/2     Discriminator Loss: 1.3827     Generator Loss: 1.7643
# Epoch 1/2     Discriminator Loss: 1.4360     Generator Loss: 1.7613
# Epoch 1/2     Discriminator Loss: 1.3248     Generator Loss: 1.7588
# Epoch 1/2     Discriminator Loss: 1.4657     Generator Loss: 1.7393
# Epoch 1/2     Discriminator Loss: 1.4300     Generator Loss: 1.8469
# Epoch 1/2     Discriminator Loss: 1.4153     Generator Loss: 1.7420
# Epoch 1/2     Discriminator Loss: 1.3750     Generator Loss: 1.7669
# Epoch 1/2     Discriminator Loss: 1.3406     Generator Loss: 1.7179
# Epoch 1/2     Discriminator Loss: 1.4293     Generator Loss: 1.7910
# Epoch 1/2     Discriminator Loss: 1.4317     Generator Loss: 1.7734
# Epoch 1/2     Discriminator Loss: 1.4504     Generator Loss: 1.7927
# Epoch 1/2     Discriminator Loss: 1.4433     Generator Loss: 1.7689
# Epoch 1/2     Discriminator Loss: 1.4517     Generator Loss: 1.7223
# Epoch 1/2     Discriminator Loss: 1.3882     Generator Loss: 1.7929
# Epoch 1/2     Discriminator Loss: 1.4876     Generator Loss: 1.7106
# Epoch 1/2     Discriminator Loss: 1.4619     Generator Loss: 1.7343
# Epoch 1/2     Discriminator Loss: 1.3364     Generator Loss: 1.7501
# Epoch 1/2     Discriminator Loss: 1.4107     Generator Loss: 1.7708
# Epoch 1/2     Discriminator Loss: 1.4276     Generator Loss: 1.7433
# Epoch 1/2     Discriminator Loss: 1.4014     Generator Loss: 1.7591
# Epoch 1/2     Discriminator Loss: 1.4777     Generator Loss: 1.7591
# Epoch 1/2     Discriminator Loss: 1.4139     Generator Loss: 1.6886
# Epoch 1/2     Discriminator Loss: 1.4225     Generator Loss: 1.7595
# Epoch 1/2     Discriminator Loss: 1.4331     Generator Loss: 1.7262
# Epoch 1/2     Discriminator Loss: 1.4128     Generator Loss: 1.7352
# Epoch 1/2     Discriminator Loss: 1.4631     Generator Loss: 1.6904
# Epoch 1/2     Discriminator Loss: 1.3988     Generator Loss: 1.7080
# Epoch 1/2     Discriminator Loss: 1.4408     Generator Loss: 1.7883
# Epoch 1/2     Discriminator Loss: 1.4466     Generator Loss: 1.7231
# Epoch 1/2     Discriminator Loss: 1.4075     Generator Loss: 1.6828
# Epoch 1/2     Discriminator Loss: 1.3963     Generator Loss: 1.7063
# Epoch 1/2     Discriminator Loss: 1.5206     Generator Loss: 1.7440
# Epoch 1/2     Discriminator Loss: 1.4089     Generator Loss: 1.7674
# Epoch 1/2     Discriminator Loss: 1.3828     Generator Loss: 1.7212
# Epoch 1/2     Discriminator Loss: 1.4198     Generator Loss: 1.6733
# Epoch 1/2     Discriminator Loss: 1.4730     Generator Loss: 1.7329
# Epoch 1/2     Discriminator Loss: 1.4655     Generator Loss: 1.7380
# Epoch 1/2     Discriminator Loss: 1.3691     Generator Loss: 1.7572
# Epoch 1/2     Discriminator Loss: 1.4175     Generator Loss: 1.7268
# Epoch 1/2     Discriminator Loss: 1.4457     Generator Loss: 1.7429
# Epoch 1/2     Discriminator Loss: 1.3671     Generator Loss: 1.7138
# Epoch 1/2     Discriminator Loss: 1.4616     Generator Loss: 1.7441
# Epoch 1/2     Discriminator Loss: 1.3606     Generator Loss: 1.7296
# Epoch 1/2     Discriminator Loss: 1.4350     Generator Loss: 1.7174
# Epoch 1/2     Discriminator Loss: 1.3511     Generator Loss: 1.7781
# Epoch 1/2     Discriminator Loss: 1.4707     Generator Loss: 1.7415
# Epoch 1/2     Discriminator Loss: 1.3545     Generator Loss: 1.7169
# Epoch 1/2     Discriminator Loss: 1.4038     Generator Loss: 1.7336
# Epoch 1/2     Discriminator Loss: 1.4601     Generator Loss: 1.7589
# Epoch 1/2     Discriminator Loss: 1.4104     Generator Loss: 1.7553
# Epoch 1/2     Discriminator Loss: 1.4456     Generator Loss: 1.6919
# Epoch 1/2     Discriminator Loss: 1.4268     Generator Loss: 1.7119
# Epoch 1/2     Discriminator Loss: 1.3969     Generator Loss: 1.7758
# Epoch 1/2     Discriminator Loss: 1.3815     Generator Loss: 1.8265
# Epoch 1/2     Discriminator Loss: 1.4269     Generator Loss: 1.7598
# Epoch 1/2     Discriminator Loss: 1.4119     Generator Loss: 1.7272
# Epoch 1/2     Discriminator Loss: 1.4784     Generator Loss: 1.7656
# Epoch 1/2     Discriminator Loss: 1.4474     Generator Loss: 1.7026
# Epoch 1/2     Discriminator Loss: 1.3721     Generator Loss: 1.6877
# Epoch 1/2     Discriminator Loss: 1.3735     Generator Loss: 1.7466
# Epoch 1/2     Discriminator Loss: 1.4270     Generator Loss: 1.7404
# Epoch 1/2     Discriminator Loss: 1.4125     Generator Loss: 1.7603
# Epoch 1/2     Discriminator Loss: 1.4771     Generator Loss: 1.7557
# Epoch 1/2     Discriminator Loss: 1.4548     Generator Loss: 1.7523
# Epoch 1/2     Discriminator Loss: 1.4387     Generator Loss: 1.7291
# Epoch 1/2     Discriminator Loss: 1.4149     Generator Loss: 1.6992
# Epoch 1/2     Discriminator Loss: 1.4262     Generator Loss: 1.7628
# Epoch 1/2     Discriminator Loss: 1.3629     Generator Loss: 1.7560
# Epoch 1/2     Discriminator Loss: 1.3954     Generator Loss: 1.7094
# Epoch 1/2     Discriminator Loss: 1.4365     Generator Loss: 1.7291
# Epoch 1/2     Discriminator Loss: 1.4725     Generator Loss: 1.7579
# Epoch 1/2     Discriminator Loss: 1.4252     Generator Loss: 1.7547
# Epoch 1/2     Discriminator Loss: 1.4071     Generator Loss: 1.7680
# Epoch 1/2     Discriminator Loss: 1.3967     Generator Loss: 1.7419
# Epoch 1/2     Discriminator Loss: 1.4033     Generator Loss: 1.6744
# Epoch 1/2     Discriminator Loss: 1.4632     Generator Loss: 1.7367
# Epoch 1/2     Discriminator Loss: 1.4054     Generator Loss: 1.7380
# Epoch 1/2     Discriminator Loss: 1.4345     Generator Loss: 1.7649
# Epoch 1/2     Discriminator Loss: 1.3882     Generator Loss: 1.7726
# Epoch 1/2     Discriminator Loss: 1.4092     Generator Loss: 1.7298
# Epoch 1/2     Discriminator Loss: 1.3780     Generator Loss: 1.6979
# Epoch 1/2     Discriminator Loss: 1.4963     Generator Loss: 1.7794
# Epoch 1/2     Discriminator Loss: 1.5023     Generator Loss: 1.6873
# Epoch 1/2     Discriminator Loss: 1.4201     Generator Loss: 1.7509
# Epoch 1/2     Discriminator Loss: 1.4682     Generator Loss: 1.7620
# Epoch 1/2     Discriminator Loss: 1.3497     Generator Loss: 1.6797
# Epoch 1/2     Discriminator Loss: 1.4390     Generator Loss: 1.7534
# Epoch 1/2     Discriminator Loss: 1.3988     Generator Loss: 1.7628
# Epoch 1/2     Discriminator Loss: 1.4000     Generator Loss: 1.7492
# Epoch 1/2     Discriminator Loss: 1.3941     Generator Loss: 1.7197
# Epoch 1/2     Discriminator Loss: 1.4358     Generator Loss: 1.7901
# Epoch 1/2     Discriminator Loss: 1.4450     Generator Loss: 1.7083
# Epoch 1/2     Discriminator Loss: 1.4381     Generator Loss: 1.7226
# Epoch 1/2     Discriminator Loss: 1.4257     Generator Loss: 1.7521
# Epoch 1/2     Discriminator Loss: 1.4545     Generator Loss: 1.8104
# Epoch 1/2     Discriminator Loss: 1.4011     Generator Loss: 1.7125
# Epoch 1/2     Discriminator Loss: 1.4294     Generator Loss: 1.8079
# Epoch 1/2     Discriminator Loss: 1.4259     Generator Loss: 1.7627
# Epoch 1/2     Discriminator Loss: 1.3928     Generator Loss: 1.7411
# Epoch 1/2     Discriminator Loss: 1.4360     Generator Loss: 1.7834
# Epoch 1/2     Discriminator Loss: 1.4288     Generator Loss: 1.7293
# Epoch 1/2     Discriminator Loss: 1.4123     Generator Loss: 1.7502
# Epoch 1/2     Discriminator Loss: 1.4164     Generator Loss: 1.7707
# Epoch 1/2     Discriminator Loss: 1.4116     Generator Loss: 1.7504
# Epoch 1/2     Discriminator Loss: 1.4123     Generator Loss: 1.7673
# Epoch 1/2     Discriminator Loss: 1.3664     Generator Loss: 1.7141
# Epoch 1/2     Discriminator Loss: 1.3715     Generator Loss: 1.7667
# Epoch 1/2     Discriminator Loss: 1.4354     Generator Loss: 1.7818
# Epoch 1/2     Discriminator Loss: 1.3968     Generator Loss: 1.7407
# Epoch 1/2     Discriminator Loss: 1.4767     Generator Loss: 1.7238
# Epoch 1/2     Discriminator Loss: 1.4529     Generator Loss: 1.7545
# Epoch 1/2     Discriminator Loss: 1.3895     Generator Loss: 1.7810
# Epoch 1/2     Discriminator Loss: 1.5045     Generator Loss: 1.7865
# Epoch 1/2     Discriminator Loss: 1.3850     Generator Loss: 1.6869
# Epoch 1/2     Discriminator Loss: 1.4683     Generator Loss: 1.7763
# Epoch 1/2     Discriminator Loss: 1.4606     Generator Loss: 1.7153
# Epoch 1/2     Discriminator Loss: 1.3930     Generator Loss: 1.7463
# Epoch 1/2     Discriminator Loss: 1.4050     Generator Loss: 1.7346
# Epoch 1/2     Discriminator Loss: 1.4342     Generator Loss: 1.7439
# Epoch 1/2     Discriminator Loss: 1.4298     Generator Loss: 1.6899
# Epoch 1/2     Discriminator Loss: 1.4021     Generator Loss: 1.7286
# Epoch 1/2     Discriminator Loss: 1.4712     Generator Loss: 1.7738
# Epoch 1/2     Discriminator Loss: 1.3087     Generator Loss: 1.7188
# Epoch 1/2     Discriminator Loss: 1.4591     Generator Loss: 1.7199
# Epoch 1/2     Discriminator Loss: 1.3513     Generator Loss: 1.7178
# Epoch 1/2     Discriminator Loss: 1.4622     Generator Loss: 1.6891
# Epoch 1/2     Discriminator Loss: 1.4538     Generator Loss: 1.6950
# Epoch 1/2     Discriminator Loss: 1.4563     Generator Loss: 1.7315
# Epoch 1/2     Discriminator Loss: 1.3967     Generator Loss: 1.7273
# Epoch 1/2     Discriminator Loss: 1.4771     Generator Loss: 1.8040
# Epoch 1/2     Discriminator Loss: 1.4272     Generator Loss: 1.7439
# Epoch 1/2     Discriminator Loss: 1.4532     Generator Loss: 1.8123
# Epoch 1/2     Discriminator Loss: 1.3984     Generator Loss: 1.7030
# Epoch 1/2     Discriminator Loss: 1.4009     Generator Loss: 1.7502
# Epoch 1/2     Discriminator Loss: 1.4405     Generator Loss: 1.6996
# Epoch 1/2     Discriminator Loss: 1.4430     Generator Loss: 1.7193
# Epoch 1/2     Discriminator Loss: 1.4450     Generator Loss: 1.7199
# Epoch 1/2     Discriminator Loss: 1.3501     Generator Loss: 1.7479
# Epoch 1/2     Discriminator Loss: 1.4661     Generator Loss: 1.7979
# Epoch 1/2     Discriminator Loss: 1.3925     Generator Loss: 1.7380
# Epoch 1/2     Discriminator Loss: 1.3973     Generator Loss: 1.7202
# Epoch 1/2     Discriminator Loss: 1.4083     Generator Loss: 1.6619
# Epoch 1/2     Discriminator Loss: 1.3769     Generator Loss: 1.8077
# Epoch 1/2     Discriminator Loss: 1.4566     Generator Loss: 1.7467
# Epoch 1/2     Discriminator Loss: 1.3560     Generator Loss: 1.7439
# Epoch 1/2     Discriminator Loss: 1.3868     Generator Loss: 1.7460
# Epoch 1/2     Discriminator Loss: 1.4212     Generator Loss: 1.7669
# Epoch 1/2     Discriminator Loss: 1.3610     Generator Loss: 1.7387
# Epoch 1/2     Discriminator Loss: 1.3916     Generator Loss: 1.7505
# Epoch 1/2     Discriminator Loss: 1.4500     Generator Loss: 1.7388
# Epoch 1/2     Discriminator Loss: 1.3675     Generator Loss: 1.7807
# Epoch 1/2     Discriminator Loss: 1.4464     Generator Loss: 1.7398
# Epoch 1/2     Discriminator Loss: 1.4536     Generator Loss: 1.7556
# Epoch 1/2     Discriminator Loss: 1.4071     Generator Loss: 1.6944
# Epoch 1/2     Discriminator Loss: 1.4014     Generator Loss: 1.7044
# Epoch 1/2     Discriminator Loss: 1.4205     Generator Loss: 1.8137
# Epoch 1/2     Discriminator Loss: 1.4128     Generator Loss: 1.7516
# Epoch 1/2     Discriminator Loss: 1.3817     Generator Loss: 1.7944
# Epoch 1/2     Discriminator Loss: 1.4726     Generator Loss: 1.7764
# Epoch 1/2     Discriminator Loss: 1.3847     Generator Loss: 1.7984
# Epoch 1/2     Discriminator Loss: 1.4411     Generator Loss: 1.7277
# Epoch 1/2     Discriminator Loss: 1.3982     Generator Loss: 1.8251
# Epoch 1/2     Discriminator Loss: 1.4552     Generator Loss: 1.7543
# Epoch 1/2     Discriminator Loss: 1.4608     Generator Loss: 1.6962
# Epoch 1/2     Discriminator Loss: 1.4363     Generator Loss: 1.8226
# Epoch 1/2     Discriminator Loss: 1.4317     Generator Loss: 1.6640
# Epoch 1/2     Discriminator Loss: 1.4778     Generator Loss: 1.7622
# Epoch 1/2     Discriminator Loss: 1.4474     Generator Loss: 1.7775
# Epoch 1/2     Discriminator Loss: 1.4318     Generator Loss: 1.7566
# Epoch 1/2     Discriminator Loss: 1.4833     Generator Loss: 1.7425
# Epoch 1/2     Discriminator Loss: 1.3935     Generator Loss: 1.7880
# Epoch 1/2     Discriminator Loss: 1.4383     Generator Loss: 1.8024
# Epoch 1/2     Discriminator Loss: 1.3409     Generator Loss: 1.7449
# Epoch 1/2     Discriminator Loss: 1.3882     Generator Loss: 1.7367
# Epoch 1/2     Discriminator Loss: 1.4680     Generator Loss: 1.7800
# Epoch 1/2     Discriminator Loss: 1.3969     Generator Loss: 1.7281
# Epoch 1/2     Discriminator Loss: 1.3665     Generator Loss: 1.7851
# Epoch 1/2     Discriminator Loss: 1.4060     Generator Loss: 1.7105
# Epoch 1/2     Discriminator Loss: 1.4120     Generator Loss: 1.6862
# Epoch 1/2     Discriminator Loss: 1.4200     Generator Loss: 1.8210
# Epoch 1/2     Discriminator Loss: 1.4124     Generator Loss: 1.6977
# Epoch 1/2     Discriminator Loss: 1.3410     Generator Loss: 1.6777
# Epoch 1/2     Discriminator Loss: 1.4590     Generator Loss: 1.7809
# Epoch 1/2     Discriminator Loss: 1.4297     Generator Loss: 1.7388
# Epoch 1/2     Discriminator Loss: 1.4027     Generator Loss: 1.7548
# Epoch 1/2     Discriminator Loss: 1.4150     Generator Loss: 1.7221
# Epoch 1/2     Discriminator Loss: 1.3969     Generator Loss: 1.7846
# Epoch 1/2     Discriminator Loss: 1.4322     Generator Loss: 1.8207
# Epoch 1/2     Discriminator Loss: 1.4599     Generator Loss: 1.7370
# Epoch 1/2     Discriminator Loss: 1.4576     Generator Loss: 1.8081
# Epoch 1/2     Discriminator Loss: 1.4313     Generator Loss: 1.7773
# Epoch 1/2     Discriminator Loss: 1.4400     Generator Loss: 1.7202
# Epoch 1/2     Discriminator Loss: 1.4518     Generator Loss: 1.7449
# Epoch 1/2     Discriminator Loss: 1.4244     Generator Loss: 1.7416
# Epoch 1/2     Discriminator Loss: 1.4204     Generator Loss: 1.8430
# Epoch 1/2     Discriminator Loss: 1.4164     Generator Loss: 1.7181
# Epoch 1/2     Discriminator Loss: 1.4280     Generator Loss: 1.7646
# Epoch 1/2     Discriminator Loss: 1.4287     Generator Loss: 1.7218
# Epoch 1/2     Discriminator Loss: 1.3886     Generator Loss: 1.8148
# Epoch 1/2     Discriminator Loss: 1.3955     Generator Loss: 1.8099
# Epoch 1/2     Discriminator Loss: 1.4242     Generator Loss: 1.7827
# Epoch 1/2     Discriminator Loss: 1.4265     Generator Loss: 1.7264
# Epoch 1/2     Discriminator Loss: 1.3937     Generator Loss: 1.7382
# Epoch 1/2     Discriminator Loss: 1.4543     Generator Loss: 1.7555
# Epoch 1/2     Discriminator Loss: 1.3802     Generator Loss: 1.7573
# Epoch 1/2     Discriminator Loss: 1.3958     Generator Loss: 1.7973
# Epoch 1/2     Discriminator Loss: 1.4596     Generator Loss: 1.7470
# Epoch 1/2     Discriminator Loss: 1.4132     Generator Loss: 1.7592
# Epoch 1/2     Discriminator Loss: 1.4168     Generator Loss: 1.7177
# Epoch 1/2     Discriminator Loss: 1.3462     Generator Loss: 1.7837
# Epoch 1/2     Discriminator Loss: 1.4605     Generator Loss: 1.7516
# Epoch 1/2     Discriminator Loss: 1.3909     Generator Loss: 1.7553
# Epoch 1/2     Discriminator Loss: 1.4113     Generator Loss: 1.7588
# Epoch 1/2     Discriminator Loss: 1.4727     Generator Loss: 1.8053
# Epoch 1/2     Discriminator Loss: 1.4077     Generator Loss: 1.7410
# Epoch 1/2     Discriminator Loss: 1.4503     Generator Loss: 1.7639
# Epoch 1/2     Discriminator Loss: 1.4207     Generator Loss: 1.7182
# Epoch 1/2     Discriminator Loss: 1.4171     Generator Loss: 1.7397
# Epoch 1/2     Discriminator Loss: 1.4180     Generator Loss: 1.7899
# Epoch 1/2     Discriminator Loss: 1.4325     Generator Loss: 1.7222
# Epoch 1/2     Discriminator Loss: 1.5097     Generator Loss: 1.7285
# Epoch 1/2     Discriminator Loss: 1.4303     Generator Loss: 1.7230
# Epoch 1/2     Discriminator Loss: 1.4402     Generator Loss: 1.7444
# Epoch 1/2     Discriminator Loss: 1.3802     Generator Loss: 1.7226
# Epoch 1/2     Discriminator Loss: 1.4247     Generator Loss: 1.7438
# Epoch 1/2     Discriminator Loss: 1.4145     Generator Loss: 1.7302
# Epoch 1/2     Discriminator Loss: 1.3803     Generator Loss: 1.7542
# Epoch 1/2     Discriminator Loss: 1.3892     Generator Loss: 1.8150
# Epoch 1/2     Discriminator Loss: 1.4653     Generator Loss: 1.7671
# Epoch 1/2     Discriminator Loss: 1.4459     Generator Loss: 1.7611
# Epoch 1/2     Discriminator Loss: 1.4458     Generator Loss: 1.7725
# Epoch 1/2     Discriminator Loss: 1.3585     Generator Loss: 1.7360
# Epoch 1/2     Discriminator Loss: 1.4333     Generator Loss: 1.7626
# Epoch 1/2     Discriminator Loss: 1.4407     Generator Loss: 1.7330
# Epoch 1/2     Discriminator Loss: 1.3681     Generator Loss: 1.7915
# Epoch 1/2     Discriminator Loss: 1.4917     Generator Loss: 1.7564
# Epoch 1/2     Discriminator Loss: 1.4315     Generator Loss: 1.6778
# Epoch 1/2     Discriminator Loss: 1.3797     Generator Loss: 1.7804
# Epoch 1/2     Discriminator Loss: 1.3668     Generator Loss: 1.7278
# Epoch 1/2     Discriminator Loss: 1.4240     Generator Loss: 1.7656
# Epoch 1/2     Discriminator Loss: 1.4039     Generator Loss: 1.7091
# Epoch 1/2     Discriminator Loss: 1.4773     Generator Loss: 1.7540
# Epoch 1/2     Discriminator Loss: 1.4043     Generator Loss: 1.7561
# Epoch 1/2     Discriminator Loss: 1.4241     Generator Loss: 1.7607
# Epoch 1/2     Discriminator Loss: 1.3840     Generator Loss: 1.8155
# Epoch 1/2     Discriminator Loss: 1.4293     Generator Loss: 1.7630
# Epoch 1/2     Discriminator Loss: 1.4021     Generator Loss: 1.7627
# Epoch 1/2     Discriminator Loss: 1.3628     Generator Loss: 1.7089
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-619d406e1ae7> in <module>()
#      16 with tf.Graph().as_default():
#      17     train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
# ---> 18           mnist_dataset.shape, mnist_dataset.image_mode)
#      19
#      20
#
# <ipython-input-33-30add4696aaa> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      44
#      45                 while steps % print_batch == 0:
# ---> 46                     train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
#      47                     train_loss_g = g_loss.eval({input_z: batch_z})
#      48
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     565
#     566     """
# --> 567     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     568
#     569
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3727                        "the tensor's graph is different from the session's "
#    3728                        "graph.")
# -> 3729   return session.run(tensors, feed_dict)
#    3730
#    3731
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### CelebA
# 在 CelebA 上运行你的 GANs 模型。在一般的GPU上运行每次迭代大约需要 20 分钟。你可以运行整个迭代，或者当 GANs 开始产生真实人脸图像时停止它。

# %%
batch_size = 16
z_dim = 100
learning_rate = 0.001
beta1 = 0.5


CelebA_start_time = time.time()

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
    

CelebA_end_time = time.time()
print("\nTime cost: {:.2f} minutes".format((CelebA_end_time - CelebA_start_time) / 60))
# Out:
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3459
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3135
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4271
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4462
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2957
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3674
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2710
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4231
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3747
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3401
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2783
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3892
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3905
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4656
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4205
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2601
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3413
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4746
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3420
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2919
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3443
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4553
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3135
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3996
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3447
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4741
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3953
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4395
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4220
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3922
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4533
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3834
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3675
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3476
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3192
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2927
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4396
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3566
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3470
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4050
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4089
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4074
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3737
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3761
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3772
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4454
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3671
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4221
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2901
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3785
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3772
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4163
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4225
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4113
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4515
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3172
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3816
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3758
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3831
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4022
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3417
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3912
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4868
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3280
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4491
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3372
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3213
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3603
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4199
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4442
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3395
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2524
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3876
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3210
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4212
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3682
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4272
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4005
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3862
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3944
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3299
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3451
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4435
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3846
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4225
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4198
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4222
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4481
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4333
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3721
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3327
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3342
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3609
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3790
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4083
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3356
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3479
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.5286
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4084
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3682
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3373
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4372
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3248
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3551
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4181
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3450
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3247
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3767
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4382
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3823
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4103
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3630
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3130
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4685
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4304
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4472
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3973
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4134
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3593
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3833
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4518
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.5009
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4730
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4269
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3899
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3500
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2842
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3768
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4986
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3618
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4215
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2958
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3923
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3762
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3686
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4030
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3764
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3399
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3682
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3827
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3580
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.1981
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3826
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4104
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4194
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3326
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4617
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3675
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3002
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4006
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3971
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3757
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3790
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3839
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4755
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4610
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3702
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4141
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2920
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3807
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3283
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4263
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3506
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4548
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3697
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3933
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3918
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3431
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3085
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.5141
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3973
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3951
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3581
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3306
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4232
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3159
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4059
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3823
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3655
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3519
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3411
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4242
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4236
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4214
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3885
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3156
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4139
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3508
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3183
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3893
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3832
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3785
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3486
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3620
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3054
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3160
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4372
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3491
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3398
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3609
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3721
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3926
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4091
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3217
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3643
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3777
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3709
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4007
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3363
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3226
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3984
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3671
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3051
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3771
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4195
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4614
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4726
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3279
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3495
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4123
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4104
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3605
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4102
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3850
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4055
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4459
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3507
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4482
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4365
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4153
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2746
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3771
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4077
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3594
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3885
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3196
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3973
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3918
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4499
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2614
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3768
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3198
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4451
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4893
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3754
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4106
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3804
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3846
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3907
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3791
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3822
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3512
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4232
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3952
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4044
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3551
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3848
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4008
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3994
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3870
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4306
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4445
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3486
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4099
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4456
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4290
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3002
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3665
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4050
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4185
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4250
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3570
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2975
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4095
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4430
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3484
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3594
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4077
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4239
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3762
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3844
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3680
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4293
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3136
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3711
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4376
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3691
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4381
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3958
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3978
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3208
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3167
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3633
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3490
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4663
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4004
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2795
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3985
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3707
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3431
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3865
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3942
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4398
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4095
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4425
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2766
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3858
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3124
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3958
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3563
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3592
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4295
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3509
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3887
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3776
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3949
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4194
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3489
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3649
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3304
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3798
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3561
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4789
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4200
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3805
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4048
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3876
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4165
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3341
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4175
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4106
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3638
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4320
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3598
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3995
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4547
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4376
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3290
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4208
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3182
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3349
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4530
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3917
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4360
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4172
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3427
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3478
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3317
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4099
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3722
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4109
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3070
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2990
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3368
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3978
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3752
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4035
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3624
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3447
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3478
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3577
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3781
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4643
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3789
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3368
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4188
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4039
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4613
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3997
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4382
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4111
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4110
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3743
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4363
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4707
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3681
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3684
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3317
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3835
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4177
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4363
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3646
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4338
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3954
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3597
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3621
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4099
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3975
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4325
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3507
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3827
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3412
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3621
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2316
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4217
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4171
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3147
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3940
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4133
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4847
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4112
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4293
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4496
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4029
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4176
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3790
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3383
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3968
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3751
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3951
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3303
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4441
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3972
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.2913
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3810
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3809
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3211
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.4116
# Epoch 1/1     Discriminator Loss: 0.0001     Generator Loss: 13.3689
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-993b10a9b2c7> in <module>()
#      15 with tf.Graph().as_default():
#      16     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 17           celeba_dataset.shape, celeba_dataset.image_mode)
#      18
#      19
#
# <ipython-input-11-07aa0bb40007> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      44
#      45                 while steps % print_batch == 0:
# ---> 46                     train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
#      47                     train_loss_g = g_loss.eval({input_z: batch_z})
#      48
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     565
#     566     """
# --> 567     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     568
#     569
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3727                        "the tensor's graph is different from the session's "
#    3728                        "graph.")
# -> 3729   return session.run(tensors, feed_dict)
#    3730
#    3731
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 提交项目
# 提交本项目前，确保运行所有 cells 后保存该文件。
#
# 保存该文件为 "dlnd_face_generation.ipynb"， 并另存为 HTML 格式 "File" -> "Download as"。提交项目时请附带 "helper.py" 和 "problem_unittests.py" 文件。
